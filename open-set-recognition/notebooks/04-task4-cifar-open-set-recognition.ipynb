# %%
# !git clone https://github.com/alihasnaink/beyond-iid
# Out:
# Cloning into 'beyond-iid'...
# remote: Enumerating objects: 231, done.
# remote: Counting objects: 100% (231/231), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 231 (delta 48), reused 211 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (231/231), 40.76 MiB | 50.11 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
from pathlib import Path
import sys, json
from IPython.display import display, Image, Markdown
candidates = [Path.cwd() / 'open-set-recognition', Path.cwd(), Path('/kaggle/working/beyond-iid/open-set-recognition')]
TASK_DIR = next((p.resolve() for p in candidates if (p / 'train.py').exists()), None)
if TASK_DIR is None:
    raise FileNotFoundError('Run this notebook from the repository, or update TASK_DIR to the cloned open-set-recognition directory.')
sys.path.insert(0, str(TASK_DIR))
print('Task directory:', TASK_DIR)
# Out:
# Task directory: /kaggle/working/beyond-iid/open-set-recognition

# %%
from train import train_all
training = train_all(TASK_DIR, force=False)
display(training['histories'].groupby('method').tail(1))
display(training['selections'])
display(Image(filename=str(TASK_DIR / 'results/training_curves.png')))
# Out:
# 100%|██████████| 170M/170M [18:15<00:00, 156kB/s]
# vanilla epoch 1:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 2:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 3:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 4:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 5:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 6:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 7:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 8:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 9:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 10:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 11:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 12:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 13:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 14:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 15:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 16:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 17:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 18:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 19:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 20:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 21:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 22:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 23:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 24:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 25:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 26:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 27:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 28:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 29:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 30:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 31:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 32:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 33:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 34:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 35:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 36:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 37:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 38:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 39:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 40:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 41:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 42:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 43:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 44:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 45:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 46:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 47:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 48:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 49:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 50:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 51:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 52:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 53:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 54:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 55:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 56:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 57:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 58:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 59:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 60:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 61:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 62:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 63:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 64:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 65:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 66:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 67:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 68:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 69:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 70:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 71:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 72:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 73:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 74:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 75:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 76:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 77:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 78:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 79:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 80:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 81:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 82:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 83:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 84:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 85:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 86:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 87:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 88:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 89:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 90:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 91:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 92:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 93:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 94:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 95:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 96:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 97:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 98:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 99:   0%|          | 0/352 [00:00<?, ?it/s]
# vanilla epoch 100:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 1:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 2:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 3:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 4:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 5:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 6:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 7:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 8:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 9:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 10:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 11:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 12:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 13:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 14:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 15:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 16:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 17:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 18:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 19:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 20:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 21:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 22:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 23:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 24:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 25:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 26:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 27:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 28:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 29:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 30:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 31:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 32:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 33:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 34:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 35:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 36:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 37:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 38:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 39:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 40:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 41:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 42:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 43:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 44:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 45:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 46:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 47:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 48:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 49:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 50:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 51:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 52:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 53:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 54:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 55:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 56:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 57:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 58:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 59:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 60:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 61:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 62:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 63:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 64:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 65:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 66:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 67:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 68:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 69:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 70:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 71:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 72:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 73:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 74:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 75:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 76:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 77:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 78:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 79:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 80:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 81:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 82:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 83:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 84:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 85:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 86:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 87:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 88:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 89:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 90:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 91:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 92:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 93:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 94:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 95:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 96:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 97:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 98:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 99:   0%|          | 0/352 [00:00<?, ?it/s]
# gcsc epoch 100:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 1:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 2:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 3:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 4:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 5:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 6:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 7:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 8:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 9:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 10:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 11:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 12:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 13:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 14:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 15:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 16:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 17:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 18:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 19:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 20:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 21:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 22:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 23:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 24:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 25:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 26:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 27:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 28:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 29:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 30:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 31:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 32:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 33:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 34:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 35:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 36:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 37:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 38:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 39:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 40:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 41:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 42:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 43:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 44:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 45:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 46:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 47:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 48:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 49:   0%|          | 0/352 [00:00<?, ?it/s]
# proser epoch 50:   0%|          | 0/352 [00:00<?, ?it/s]
#       method  epoch  learning_rate  train_loss  train_accuracy  \
# 99   vanilla    100   2.467198e-05    0.002500        0.999711
# 199     gcsc    100   2.467198e-05    0.033973        0.989533
# 249   proser     50   9.866358e-07    0.012503        0.999933
#
#      validation_accuracy  known_ce  classifier_boundary_loss  \
# 99                0.9510       NaN                       NaN
# 199               0.9596       NaN                       NaN
# 249               0.9446  0.006471                  0.004255
#
#      data_placeholder_loss  mean_mix_lambda  different_class_pairs
# 99                     NaN              NaN                    NaN
# 199                    NaN              NaN                    NaN
# 249               0.017772         0.502411                    1.0
# {'vanilla': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/vanilla.pt',
#   'selected_epoch': 93,
#   'validation_accuracy': 0.9532,
#   'selection_data': 'CIFAR-10 validation only'},
#  'gcsc': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/gcsc.pt',
#   'selected_epoch': 99,
#   'validation_accuracy': 0.9604,
#   'selection_data': 'CIFAR-10 validation only'},
#  'proser': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/proser.pt',
#   'selected_epoch': 2,
#   'validation_accuracy': 0.952,
#   'selection_data': 'CIFAR-10 validation only'}}

# %%
manifest = json.loads((TASK_DIR / 'results/checkpoint_manifest.json').read_text())
display(manifest)
assert manifest['cifar100_used'] is False
assert set(manifest['models']) == {'vanilla', 'gcsc', 'proser'}
# Out:
# {'cifar100_used': False,
#  'models': {'vanilla': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/vanilla.pt',
#    'selected_epoch': 93,
#    'validation_accuracy': 0.9532,
#    'selection_data': 'CIFAR-10 validation only'},
#   'gcsc': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/gcsc.pt',
#    'selected_epoch': 99,
#    'validation_accuracy': 0.9604,
#    'selection_data': 'CIFAR-10 validation only'},
#   'proser': {'checkpoint': '/kaggle/working/beyond-iid/open-set-recognition/checkpoints/proser.pt',
#    'selected_epoch': 2,
#    'validation_accuracy': 0.952,
#    'selection_data': 'CIFAR-10 validation only'}}}

# %%
from extract_outputs import extract_all_outputs
extraction = extract_all_outputs(TASK_DIR, download=True, force=False)
display(extraction)
display(json.loads((TASK_DIR / 'results/protocol_lock.json').read_text()))
assert extraction['cifar100_train_used'] is False
assert extraction['near_unknown_count'] == extraction['far_unknown_count'] == 800
# Out:
# 100%|██████████| 169M/169M [22:31<00:00, 125kB/s]
# {'device': 'cuda',
#  'selection': {'vanilla': {'epoch': 93, 'validation_accuracy': 0.9532},
#   'gcsc': {'epoch': 99, 'validation_accuracy': 0.9604},
#   'proser': {'epoch': 2, 'validation_accuracy': 0.952}},
#  'known_train_count': 45000,
#  'known_validation_count': 5000,
#  'known_test_count': 10000,
#  'near_unknown_count': 800,
#  'far_unknown_count': 800,
#  'cifar100_train_used': False,
#  'protocol_lock': '/kaggle/working/beyond-iid/open-set-recognition/results/protocol_lock.json'}
# {'statement': 'Checkpoints and score definitions fixed before CIFAR-100 evaluation.',
#  'checkpoint_sha256': {'vanilla': 'dfb41f07584f3c37403b520ec7bb77343c495642819db73f8be9d2c8ef1b3f2d',
#   'gcsc': 'd391904738c07bf869a3b103d2a67aa6423a5b5da976fadd2473254fd6c3f1e1',
#   'proser': '911937556ac9f7d27c419a329721d1cca9959bed7f8cd6364b95f9c96d3391da'},
#  'score_definition_sha256': {'__init__.py': '5e87860e8434506644d0c0bd528812eefc65fd58e16058d6a2121af58244a65e',
#   'energy.py': '15c9e6d78b00ae1c44b7d7b2fe2ca5c3dce74632f3d90c8a1d4b409a9b0d9f8a',
#   'mahalanobis.py': '0a2b559e18c3f898efc08680506e2766515cf17a01f9d6cba5538860e7021505',
#   'mls.py': '4a6bb00c1fe4e47d103847b6e6a42165342f7146b009ec6facb9c719b45b5c5c',
#   'msp.py': '576e2a6f75e701390c2a4024b624e8cedb221c8420faf7b07c8bccc1341b9c43',
#   'placeholder.py': 'b78a3342a44b35af44ccec416abf2bdd091ca007ef66bbfb530c3789f31107ae'},
#  'selection': {'vanilla': {'epoch': 93, 'validation_accuracy': 0.9532},
#   'gcsc': {'epoch': 99, 'validation_accuracy': 0.9604},
#   'proser': {'epoch': 2, 'validation_accuracy': 0.952}}}

# %%
from evaluate_osr import evaluate
evaluation = evaluate(TASK_DIR, download=True)
print('Frozen Vanilla score comparison')
display(evaluation['posthoc'].style.format(precision=4))
print('Training-method comparison')
display(evaluation['trained'].style.format(precision=4))
# Out:
# Frozen Vanilla score comparison
# <style type="text/css">
# </style>
# <table id="T_32792">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32792_level0_col0" class="col_heading level0 col0" >method</th>
#       <th id="T_32792_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_32792_level0_col2" class="col_heading level0 col2" >closed_set_accuracy</th>
#       <th id="T_32792_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_32792_level0_col4" class="col_heading level0 col4" >auroc_near</th>
#       <th id="T_32792_level0_col5" class="col_heading level0 col5" >auroc_far</th>
#       <th id="T_32792_level0_col6" class="col_heading level0 col6" >auroc_all</th>
#       <th id="T_32792_level0_col7" class="col_heading level0 col7" >known_test_acceptance</th>
#       <th id="T_32792_level0_col8" class="col_heading level0 col8" >near_unknown_rejection</th>
#       <th id="T_32792_level0_col9" class="col_heading level0 col9" >far_unknown_rejection</th>
#       <th id="T_32792_level0_col10" class="col_heading level0 col10" >all_unknown_rejection</th>
#       <th id="T_32792_level0_col11" class="col_heading level0 col11" >near_fpr_at_95_tpr</th>
#       <th id="T_32792_level0_col12" class="col_heading level0 col12" >far_fpr_at_95_tpr</th>
#       <th id="T_32792_level0_col13" class="col_heading level0 col13" >all_fpr_at_95_tpr</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32792_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32792_row0_col0" class="data row0 col0" >Vanilla</td>
#       <td id="T_32792_row0_col1" class="data row0 col1" >MSP</td>
#       <td id="T_32792_row0_col2" class="data row0 col2" >0.9473</td>
#       <td id="T_32792_row0_col3" class="data row0 col3" >0.1644</td>
#       <td id="T_32792_row0_col4" class="data row0 col4" >0.8127</td>
#       <td id="T_32792_row0_col5" class="data row0 col5" >0.8881</td>
#       <td id="T_32792_row0_col6" class="data row0 col6" >0.8504</td>
#       <td id="T_32792_row0_col7" class="data row0 col7" >0.9486</td>
#       <td id="T_32792_row0_col8" class="data row0 col8" >0.2787</td>
#       <td id="T_32792_row0_col9" class="data row0 col9" >0.3950</td>
#       <td id="T_32792_row0_col10" class="data row0 col10" >0.3369</td>
#       <td id="T_32792_row0_col11" class="data row0 col11" >0.7212</td>
#       <td id="T_32792_row0_col12" class="data row0 col12" >0.6050</td>
#       <td id="T_32792_row0_col13" class="data row0 col13" >0.6631</td>
#     </tr>
#     <tr>
#       <th id="T_32792_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32792_row1_col0" class="data row1 col0" >Vanilla</td>
#       <td id="T_32792_row1_col1" class="data row1 col1" >MLS</td>
#       <td id="T_32792_row1_col2" class="data row1 col2" >0.9473</td>
#       <td id="T_32792_row1_col3" class="data row1 col3" >-5.8230</td>
#       <td id="T_32792_row1_col4" class="data row1 col4" >0.7963</td>
#       <td id="T_32792_row1_col5" class="data row1 col5" >0.8806</td>
#       <td id="T_32792_row1_col6" class="data row1 col6" >0.8384</td>
#       <td id="T_32792_row1_col7" class="data row1 col7" >0.9496</td>
#       <td id="T_32792_row1_col8" class="data row1 col8" >0.2950</td>
#       <td id="T_32792_row1_col9" class="data row1 col9" >0.4650</td>
#       <td id="T_32792_row1_col10" class="data row1 col10" >0.3800</td>
#       <td id="T_32792_row1_col11" class="data row1 col11" >0.7050</td>
#       <td id="T_32792_row1_col12" class="data row1 col12" >0.5350</td>
#       <td id="T_32792_row1_col13" class="data row1 col13" >0.6200</td>
#     </tr>
#     <tr>
#       <th id="T_32792_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32792_row2_col0" class="data row2 col0" >Vanilla</td>
#       <td id="T_32792_row2_col1" class="data row2 col1" >Energy</td>
#       <td id="T_32792_row2_col2" class="data row2 col2" >0.9473</td>
#       <td id="T_32792_row2_col3" class="data row2 col3" >-6.0317</td>
#       <td id="T_32792_row2_col4" class="data row2 col4" >0.7962</td>
#       <td id="T_32792_row2_col5" class="data row2 col5" >0.8810</td>
#       <td id="T_32792_row2_col6" class="data row2 col6" >0.8386</td>
#       <td id="T_32792_row2_col7" class="data row2 col7" >0.9497</td>
#       <td id="T_32792_row2_col8" class="data row2 col8" >0.2963</td>
#       <td id="T_32792_row2_col9" class="data row2 col9" >0.4725</td>
#       <td id="T_32792_row2_col10" class="data row2 col10" >0.3844</td>
#       <td id="T_32792_row2_col11" class="data row2 col11" >0.7037</td>
#       <td id="T_32792_row2_col12" class="data row2 col12" >0.5275</td>
#       <td id="T_32792_row2_col13" class="data row2 col13" >0.6156</td>
#     </tr>
#     <tr>
#       <th id="T_32792_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32792_row3_col0" class="data row3 col0" >Vanilla</td>
#       <td id="T_32792_row3_col1" class="data row3 col1" >Mahalanobis</td>
#       <td id="T_32792_row3_col2" class="data row3 col2" >0.9473</td>
#       <td id="T_32792_row3_col3" class="data row3 col3" >3019.9167</td>
#       <td id="T_32792_row3_col4" class="data row3 col4" >0.7944</td>
#       <td id="T_32792_row3_col5" class="data row3 col5" >0.9098</td>
#       <td id="T_32792_row3_col6" class="data row3 col6" >0.8521</td>
#       <td id="T_32792_row3_col7" class="data row3 col7" >0.9472</td>
#       <td id="T_32792_row3_col8" class="data row3 col8" >0.2662</td>
#       <td id="T_32792_row3_col9" class="data row3 col9" >0.4562</td>
#       <td id="T_32792_row3_col10" class="data row3 col10" >0.3613</td>
#       <td id="T_32792_row3_col11" class="data row3 col11" >0.7338</td>
#       <td id="T_32792_row3_col12" class="data row3 col12" >0.5437</td>
#       <td id="T_32792_row3_col13" class="data row3 col13" >0.6388</td>
#     </tr>
#   </tbody>
# </table>
# Training-method comparison
# <style type="text/css">
# </style>
# <table id="T_98ae8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98ae8_level0_col0" class="col_heading level0 col0" >method</th>
#       <th id="T_98ae8_level0_col1" class="col_heading level0 col1" >score</th>
#       <th id="T_98ae8_level0_col2" class="col_heading level0 col2" >closed_set_accuracy</th>
#       <th id="T_98ae8_level0_col3" class="col_heading level0 col3" >threshold</th>
#       <th id="T_98ae8_level0_col4" class="col_heading level0 col4" >auroc_near</th>
#       <th id="T_98ae8_level0_col5" class="col_heading level0 col5" >auroc_far</th>
#       <th id="T_98ae8_level0_col6" class="col_heading level0 col6" >auroc_all</th>
#       <th id="T_98ae8_level0_col7" class="col_heading level0 col7" >known_test_acceptance</th>
#       <th id="T_98ae8_level0_col8" class="col_heading level0 col8" >near_unknown_rejection</th>
#       <th id="T_98ae8_level0_col9" class="col_heading level0 col9" >far_unknown_rejection</th>
#       <th id="T_98ae8_level0_col10" class="col_heading level0 col10" >all_unknown_rejection</th>
#       <th id="T_98ae8_level0_col11" class="col_heading level0 col11" >near_fpr_at_95_tpr</th>
#       <th id="T_98ae8_level0_col12" class="col_heading level0 col12" >far_fpr_at_95_tpr</th>
#       <th id="T_98ae8_level0_col13" class="col_heading level0 col13" >all_fpr_at_95_tpr</th>
#       <th id="T_98ae8_level0_col14" class="col_heading level0 col14" >placeholder_bias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98ae8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98ae8_row0_col0" class="data row0 col0" >Vanilla</td>
#       <td id="T_98ae8_row0_col1" class="data row0 col1" >MLS</td>
#       <td id="T_98ae8_row0_col2" class="data row0 col2" >0.9473</td>
#       <td id="T_98ae8_row0_col3" class="data row0 col3" >-5.8230</td>
#       <td id="T_98ae8_row0_col4" class="data row0 col4" >0.7963</td>
#       <td id="T_98ae8_row0_col5" class="data row0 col5" >0.8806</td>
#       <td id="T_98ae8_row0_col6" class="data row0 col6" >0.8384</td>
#       <td id="T_98ae8_row0_col7" class="data row0 col7" >0.9496</td>
#       <td id="T_98ae8_row0_col8" class="data row0 col8" >0.2950</td>
#       <td id="T_98ae8_row0_col9" class="data row0 col9" >0.4650</td>
#       <td id="T_98ae8_row0_col10" class="data row0 col10" >0.3800</td>
#       <td id="T_98ae8_row0_col11" class="data row0 col11" >0.7050</td>
#       <td id="T_98ae8_row0_col12" class="data row0 col12" >0.5350</td>
#       <td id="T_98ae8_row0_col13" class="data row0 col13" >0.6200</td>
#       <td id="T_98ae8_row0_col14" class="data row0 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_98ae8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98ae8_row1_col0" class="data row1 col0" >GCSC</td>
#       <td id="T_98ae8_row1_col1" class="data row1 col1" >MLS</td>
#       <td id="T_98ae8_row1_col2" class="data row1 col2" >0.9515</td>
#       <td id="T_98ae8_row1_col3" class="data row1 col3" >-6.0972</td>
#       <td id="T_98ae8_row1_col4" class="data row1 col4" >0.8032</td>
#       <td id="T_98ae8_row1_col5" class="data row1 col5" >0.8981</td>
#       <td id="T_98ae8_row1_col6" class="data row1 col6" >0.8507</td>
#       <td id="T_98ae8_row1_col7" class="data row1 col7" >0.9468</td>
#       <td id="T_98ae8_row1_col8" class="data row1 col8" >0.3475</td>
#       <td id="T_98ae8_row1_col9" class="data row1 col9" >0.5613</td>
#       <td id="T_98ae8_row1_col10" class="data row1 col10" >0.4544</td>
#       <td id="T_98ae8_row1_col11" class="data row1 col11" >0.6525</td>
#       <td id="T_98ae8_row1_col12" class="data row1 col12" >0.4387</td>
#       <td id="T_98ae8_row1_col13" class="data row1 col13" >0.5456</td>
#       <td id="T_98ae8_row1_col14" class="data row1 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_98ae8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98ae8_row2_col0" class="data row2 col0" >PROSER</td>
#       <td id="T_98ae8_row2_col1" class="data row2 col1" >MLS</td>
#       <td id="T_98ae8_row2_col2" class="data row2 col2" >0.9441</td>
#       <td id="T_98ae8_row2_col3" class="data row2 col3" >-4.4503</td>
#       <td id="T_98ae8_row2_col4" class="data row2 col4" >0.7833</td>
#       <td id="T_98ae8_row2_col5" class="data row2 col5" >0.8352</td>
#       <td id="T_98ae8_row2_col6" class="data row2 col6" >0.8093</td>
#       <td id="T_98ae8_row2_col7" class="data row2 col7" >0.9462</td>
#       <td id="T_98ae8_row2_col8" class="data row2 col8" >0.2838</td>
#       <td id="T_98ae8_row2_col9" class="data row2 col9" >0.3775</td>
#       <td id="T_98ae8_row2_col10" class="data row2 col10" >0.3306</td>
#       <td id="T_98ae8_row2_col11" class="data row2 col11" >0.7163</td>
#       <td id="T_98ae8_row2_col12" class="data row2 col12" >0.6225</td>
#       <td id="T_98ae8_row2_col13" class="data row2 col13" >0.6694</td>
#       <td id="T_98ae8_row2_col14" class="data row2 col14" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_98ae8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98ae8_row3_col0" class="data row3 col0" >PROSER</td>
#       <td id="T_98ae8_row3_col1" class="data row3 col1" >placeholder</td>
#       <td id="T_98ae8_row3_col2" class="data row3 col2" >0.9441</td>
#       <td id="T_98ae8_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_98ae8_row3_col4" class="data row3 col4" >0.7720</td>
#       <td id="T_98ae8_row3_col5" class="data row3 col5" >0.8551</td>
#       <td id="T_98ae8_row3_col6" class="data row3 col6" >0.8135</td>
#       <td id="T_98ae8_row3_col7" class="data row3 col7" >0.9472</td>
#       <td id="T_98ae8_row3_col8" class="data row3 col8" >0.2600</td>
#       <td id="T_98ae8_row3_col9" class="data row3 col9" >0.4088</td>
#       <td id="T_98ae8_row3_col10" class="data row3 col10" >0.3344</td>
#       <td id="T_98ae8_row3_col11" class="data row3 col11" >0.7400</td>
#       <td id="T_98ae8_row3_col12" class="data row3 col12" >0.5913</td>
#       <td id="T_98ae8_row3_col13" class="data row3 col13" >0.6656</td>
#       <td id="T_98ae8_row3_col14" class="data row3 col14" >-0.7890</td>
#     </tr>
#   </tbody>
# </table>

# %%
display(Image(filename=str(TASK_DIR / 'results/vanilla_score_distributions.png')))
display(Image(filename=str(TASK_DIR / 'results/vanilla_score_agreement.png')))
display(Image(filename=str(TASK_DIR / 'results/vanilla_mls_failure_cases.png')))

# %%
print('Per-class acceptance and dominant known prediction')
display(evaluation['absorption'].style.format({'acceptance_rate': '{:.3f}', 'dominant_prediction_share': '{:.3f}'}))
print('Six Vanilla-MLS failures (three near, three far)')
display(evaluation['failures'])
print('Spearman score agreement')
display(evaluation['correlations'].style.format(precision=3))
print('Largest pairwise score-ranking disagreements')
display(evaluation['disagreements'].head(12))
display(Markdown(evaluation['report_notes']))
print('Saved artifacts:')
for path in sorted((TASK_DIR / 'results').iterdir()):
    if path.is_file(): print(' -', path.name)
# Out:
# Per-class acceptance and dominant known prediction
# <style type="text/css">
# </style>
# <table id="T_d987d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d987d_level0_col0" class="col_heading level0 col0" >method</th>
#       <th id="T_d987d_level0_col1" class="col_heading level0 col1" >group</th>
#       <th id="T_d987d_level0_col2" class="col_heading level0 col2" >unknown_class</th>
#       <th id="T_d987d_level0_col3" class="col_heading level0 col3" >acceptance_rate</th>
#       <th id="T_d987d_level0_col4" class="col_heading level0 col4" >dominant_known_prediction</th>
#       <th id="T_d987d_level0_col5" class="col_heading level0 col5" >dominant_prediction_share</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d987d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d987d_row0_col0" class="data row0 col0" >Vanilla</td>
#       <td id="T_d987d_row0_col1" class="data row0 col1" >near</td>
#       <td id="T_d987d_row0_col2" class="data row0 col2" >bus</td>
#       <td id="T_d987d_row0_col3" class="data row0 col3" >0.850</td>
#       <td id="T_d987d_row0_col4" class="data row0 col4" >truck</td>
#       <td id="T_d987d_row0_col5" class="data row0 col5" >0.788</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d987d_row1_col0" class="data row1 col0" >Vanilla</td>
#       <td id="T_d987d_row1_col1" class="data row1 col1" >near</td>
#       <td id="T_d987d_row1_col2" class="data row1 col2" >camel</td>
#       <td id="T_d987d_row1_col3" class="data row1 col3" >0.570</td>
#       <td id="T_d987d_row1_col4" class="data row1 col4" >horse</td>
#       <td id="T_d987d_row1_col5" class="data row1 col5" >0.316</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d987d_row2_col0" class="data row2 col0" >Vanilla</td>
#       <td id="T_d987d_row2_col1" class="data row2 col1" >near</td>
#       <td id="T_d987d_row2_col2" class="data row2 col2" >fox</td>
#       <td id="T_d987d_row2_col3" class="data row2 col3" >0.760</td>
#       <td id="T_d987d_row2_col4" class="data row2 col4" >deer</td>
#       <td id="T_d987d_row2_col5" class="data row2 col5" >0.395</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d987d_row3_col0" class="data row3 col0" >Vanilla</td>
#       <td id="T_d987d_row3_col1" class="data row3 col1" >near</td>
#       <td id="T_d987d_row3_col2" class="data row3 col2" >leopard</td>
#       <td id="T_d987d_row3_col3" class="data row3 col3" >0.710</td>
#       <td id="T_d987d_row3_col4" class="data row3 col4" >frog</td>
#       <td id="T_d987d_row3_col5" class="data row3 col5" >0.437</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d987d_row4_col0" class="data row4 col0" >Vanilla</td>
#       <td id="T_d987d_row4_col1" class="data row4 col1" >near</td>
#       <td id="T_d987d_row4_col2" class="data row4 col2" >motorcycle</td>
#       <td id="T_d987d_row4_col3" class="data row4 col3" >0.420</td>
#       <td id="T_d987d_row4_col4" class="data row4 col4" >automobile</td>
#       <td id="T_d987d_row4_col5" class="data row4 col5" >0.524</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d987d_row5_col0" class="data row5 col0" >Vanilla</td>
#       <td id="T_d987d_row5_col1" class="data row5 col1" >near</td>
#       <td id="T_d987d_row5_col2" class="data row5 col2" >pickup_truck</td>
#       <td id="T_d987d_row5_col3" class="data row5 col3" >0.910</td>
#       <td id="T_d987d_row5_col4" class="data row5 col4" >automobile</td>
#       <td id="T_d987d_row5_col5" class="data row5 col5" >0.670</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d987d_row6_col0" class="data row6 col0" >Vanilla</td>
#       <td id="T_d987d_row6_col1" class="data row6 col1" >near</td>
#       <td id="T_d987d_row6_col2" class="data row6 col2" >tractor</td>
#       <td id="T_d987d_row6_col3" class="data row6 col3" >0.630</td>
#       <td id="T_d987d_row6_col4" class="data row6 col4" >truck</td>
#       <td id="T_d987d_row6_col5" class="data row6 col5" >0.857</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d987d_row7_col0" class="data row7 col0" >Vanilla</td>
#       <td id="T_d987d_row7_col1" class="data row7 col1" >near</td>
#       <td id="T_d987d_row7_col2" class="data row7 col2" >wolf</td>
#       <td id="T_d987d_row7_col3" class="data row7 col3" >0.790</td>
#       <td id="T_d987d_row7_col4" class="data row7 col4" >cat</td>
#       <td id="T_d987d_row7_col5" class="data row7 col5" >0.481</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d987d_row8_col0" class="data row8 col0" >Vanilla</td>
#       <td id="T_d987d_row8_col1" class="data row8 col1" >far</td>
#       <td id="T_d987d_row8_col2" class="data row8 col2" >bottle</td>
#       <td id="T_d987d_row8_col3" class="data row8 col3" >0.450</td>
#       <td id="T_d987d_row8_col4" class="data row8 col4" >cat</td>
#       <td id="T_d987d_row8_col5" class="data row8 col5" >0.400</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d987d_row9_col0" class="data row9 col0" >Vanilla</td>
#       <td id="T_d987d_row9_col1" class="data row9 col1" >far</td>
#       <td id="T_d987d_row9_col2" class="data row9 col2" >bowl</td>
#       <td id="T_d987d_row9_col3" class="data row9 col3" >0.520</td>
#       <td id="T_d987d_row9_col4" class="data row9 col4" >cat</td>
#       <td id="T_d987d_row9_col5" class="data row9 col5" >0.365</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d987d_row10_col0" class="data row10 col0" >Vanilla</td>
#       <td id="T_d987d_row10_col1" class="data row10 col1" >far</td>
#       <td id="T_d987d_row10_col2" class="data row10 col2" >chair</td>
#       <td id="T_d987d_row10_col3" class="data row10 col3" >0.430</td>
#       <td id="T_d987d_row10_col4" class="data row10 col4" >airplane</td>
#       <td id="T_d987d_row10_col5" class="data row10 col5" >0.628</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d987d_row11_col0" class="data row11 col0" >Vanilla</td>
#       <td id="T_d987d_row11_col1" class="data row11 col1" >far</td>
#       <td id="T_d987d_row11_col2" class="data row11 col2" >clock</td>
#       <td id="T_d987d_row11_col3" class="data row11 col3" >0.490</td>
#       <td id="T_d987d_row11_col4" class="data row11 col4" >cat</td>
#       <td id="T_d987d_row11_col5" class="data row11 col5" >0.265</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d987d_row12_col0" class="data row12 col0" >Vanilla</td>
#       <td id="T_d987d_row12_col1" class="data row12 col1" >far</td>
#       <td id="T_d987d_row12_col2" class="data row12 col2" >keyboard</td>
#       <td id="T_d987d_row12_col3" class="data row12 col3" >0.450</td>
#       <td id="T_d987d_row12_col4" class="data row12 col4" >airplane</td>
#       <td id="T_d987d_row12_col5" class="data row12 col5" >0.267</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d987d_row13_col0" class="data row13 col0" >Vanilla</td>
#       <td id="T_d987d_row13_col1" class="data row13 col1" >far</td>
#       <td id="T_d987d_row13_col2" class="data row13 col2" >mushroom</td>
#       <td id="T_d987d_row13_col3" class="data row13 col3" >0.570</td>
#       <td id="T_d987d_row13_col4" class="data row13 col4" >bird</td>
#       <td id="T_d987d_row13_col5" class="data row13 col5" >0.439</td>
#     </tr>
#     <tr>
#       <th id="T_d987d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d987d_row14_col0" class="data row14 col0" >Vanilla</td>
#       <td id="T_d987d_row14_col1" class="d
# Six Vanilla-MLS failures (three near, three far)
#   group  rank          identifier  official_test_index unknown_class  \
# 0  near     1  cifar100_test:6339                 6339           bus
# 1  near     2  cifar100_test:7133                 7133           bus
# 2  near     3  cifar100_test:9261                 9261       leopard
# 3   far     1  cifar100_test:5219                 5219      mushroom
# 4   far     2  cifar100_test:6245                 6245         chair
# 5   far     3  cifar100_test:9795                 9795          bowl
#
#   predicted_known_class  unknownness_score  threshold  \
# 0                 truck         -11.847434  -5.822966
# 1                 truck         -11.795135  -5.822966
# 2                  frog         -11.567394  -5.822966
# 3                   cat         -10.995821  -5.822966
# 4              airplane         -10.983006  -5.822966
# 5              airplane         -10.964070  -5.822966
#
#                  interpretation
# 0       plausible: road vehicle
# 1       plausible: road vehicle
# 2             plausible: animal
# 3            surprising: fungus
# 4         surprising: furniture
# 5  surprising: household object
# Spearman score agreement
# <style type="text/css">
# </style>
# <table id="T_b5840">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5840_level0_col0" class="col_heading level0 col0" >MSP</th>
#       <th id="T_b5840_level0_col1" class="col_heading level0 col1" >MLS</th>
#       <th id="T_b5840_level0_col2" class="col_heading level0 col2" >Energy</th>
#       <th id="T_b5840_level0_col3" class="col_heading level0 col3" >Mahalanobis</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5840_level0_row0" class="row_heading level0 row0" >MSP</th>
#       <td id="T_b5840_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_b5840_row0_col1" class="data row0 col1" >0.957</td>
#       <td id="T_b5840_row0_col2" class="data row0 col2" >0.955</td>
#       <td id="T_b5840_row0_col3" class="data row0 col3" >0.719</td>
#     </tr>
#     <tr>
#       <th id="T_b5840_level0_row1" class="row_heading level0 row1" >MLS</th>
#       <td id="T_b5840_row1_col0" class="data row1 col0" >0.957</td>
#       <td id="T_b5840_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_b5840_row1_col2" class="data row1 col2" >1.000</td>
#       <td id="T_b5840_row1_col3" class="data row1 col3" >0.601</td>
#     </tr>
#     <tr>
#       <th id="T_b5840_level0_row2" class="row_heading level0 row2" >Energy</th>
#       <td id="T_b5840_row2_col0" class="data row2 col0" >0.955</td>
#       <td id="T_b5840_row2_col1" class="data row2 col1" >1.000</td>
#       <td id="T_b5840_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_b5840_row2_col3" class="data row2 col3" >0.599</td>
#     </tr>
#     <tr>
#       <th id="T_b5840_level0_row3" class="row_heading level0 row3" >Mahalanobis</th>
#       <td id="T_b5840_row3_col0" class="data row3 col0" >0.719</td>
#       <td id="T_b5840_row3_col1" class="data row3 col1" >0.601</td>
#       <td id="T_b5840_row3_col2" class="data row3 col2" >0.599</td>
#       <td id="T_b5840_row3_col3" class="data row3 col3" >1.000</td>
#     </tr>
#   </tbody>
# </table>
# Largest pairwise score-ranking disagreements
#          split          identifier class_name predicted_known_class score_a  \
# 25  known_test   cifar10_test:6723        dog                   dog  Energy
# 20  known_test   cifar10_test:6723        dog                   dog     MLS
# 10  known_test   cifar10_test:6723        dog                   dog     MSP
# 26  known_test   cifar10_test:9887        dog                   dog  Energy
# 21  known_test   cifar10_test:9887        dog                   dog     MLS
# 11  known_test   cifar10_test:9887        dog                   dog     MSP
# 27  known_test   cifar10_test:6554        dog                   dog  Energy
# 22  known_test   cifar10_test:6554        dog                   dog     MLS
# 12  known_test   cifar10_test:6554        dog                   dog     MSP
# 23         far  cifar100_test:9795       bowl              airplane     MLS
# 28         far  cifar100_test:9795       bowl              airplane  Energy
# 13  known_test   cifar10_test:4915        dog                   dog     MSP
#
#         score_b    value_a      value_b  percentile_a  percentile_b  \
# 25  Mahalanobis -12.605920  3684.792969      0.002586      0.953448
# 20  Mahalanobis -12.605887  3684.792969      0.002586      0.953448
# 10  Mahalanobis   0.000033  3684.792969      0.014397      0.953448
# 26  Mahalanobis -12.504916  3519.839844      0.003793      0.942500
# 21  Mahalanobis -12.504874  3519.839844      0.003793      0.942500
# 11  Mahalanobis   0.000042  3519.839844      0.023836      0.942500
# 27  Mahalanobis -13.454967  2833.697266      0.000517      0.890517
# 22  Mahalanobis -13.454961  2833.697266      0.000517      0.890517
# 12  Mahalanobis   0.000006  2833.697266      0.000733      0.890517
# 23  Mahalanobis -10.964070  3236.602539      0.055000      0.920776
# 28  Mahalanobis -10.964412  3236.602539      0.055000      0.920776
# 13  Mahalanobis   0.000002  2465.917480      0.000172      0.863190
#
#     absolute_rank_gap
# 25           0.950862
# 20           0.950862
# 10           0.939052
# 26           0.938707
# 21           0.938707
# 11           0.918664
# 27           0.890000
# 22           0.890000
# 12           0.889784
# 23           0.865776
# 28           0.865776
# 13           0.863017
# # Task 4 report notes (generated from this run)
#
# These are quantitative prompts, not claims to copy without inspecting the figures and failure images.
#
# ## Frozen-score comparison
#
# - Best near AUROC: **MSP** (0.8127); best far AUROC: **Mahalanobis** (0.9098); best all-unknown AUROC: **Mahalanobis** (0.8521).
# - Strongest score rank agreement is MLS vs Energy (Spearman 1.000); weakest is Energy vs Mahalanobis (0.599). Inspect `vanilla_score_rank_disagreements.csv` before explaining why.
#
# ## Positive augmentation and placeholders
#
# - GCSC minus Vanilla: CSA +0.0042, near AUROC +0.0069, far AUROC +0.0175.
# - PROSER-MLS minus Vanilla: CSA -0.0032, near AUROC -0.0129, far AUROC -0.0454.
# - PROSER placeholder versus its MLS: near AUROC -0.0113, far AUROC +0.0199. Relate any gains to classifier/data placeholders, while noting that between-class interpolations cannot cover every unknown direction.
#
# ## Semantic difficulty and failures
#
# - Vanilla most often accepts near class **pickup_truck** (91.0%); accepted examples are most often labeled **automobile**.
# - Vanilla most often accepts near class **bus** (85.0%); accepted examples are most often labeled **truck**.
# - Vanilla most often accepts far class **wardrobe** (79.0%); accepted examples are most often labeled **cat**.
# - Vanilla most often accepts far class **sunflower** (58.0%); accepted examples are most often labeled **bird**.
#
# - The qualitative sheet contains 6 accepted unknowns. Discuss whether each mapping is semantically plausible or surprising; do not use these observations to tune the system.
#
# ## Interpretation reminder
#
# AUROC summarizes ranking across thresholds; validation-calibrated rejection describes one operating point. Discuss both, and do not infer broad unknown robustness from the fixed near/far class sets.
# Saved artifacts:
#  - .gitkeep
#  - checkpoint_manifest.json
#  - checkpoint_selection.csv
#  - completion_audit.json
#  - extraction_manifest.json
#  - gcsc_training_history.csv
#  - posthoc_score_comparison.csv
#  - proser_loss_curves.png
#  - proser_training_history.csv
#  - protocol_lock.json
#  - report_notes.md
#  - trained_method_comparison.csv
#  - training_curves.png
#  - training_history_all_models.csv
#  - unknown_class_absorption.csv
#  - unknown_class_groups.json
#  - unknown_evaluation_manifest.csv
#  - vanilla_mls_failure_cases.csv
#  - vanilla_mls_failure_cases.png
#  - vanilla_score_agreement.png
#  - vanilla_score_distributions.png
#  - vanilla_score_rank_disagreements.csv
#  - vanilla_score_spearman_correlations.csv
#  - vanilla_training_history.csv

# %%
from pathlib import Path
import shutil
from IPython.display import FileLink, display
folder = Path("/kaggle/working/beyond-iid/open-set-recognition/results")
zip_path = Path("/kaggle/working/beyond-iid/open-set-recognition/results.zip")
shutil.make_archive(str(zip_path.with_suffix("")), "zip", root_dir=folder)
display(FileLink(str(zip_path)))
# Out:
# /kaggle/working/beyond-iid/open-set-recognition/results.zip
